# %%
import pandas as pd

df = pd.read_csv("Rat_Sightings.csv")
df.head()
# Out:
# /home/mathi/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unique Key            Created Date Closed Date Agency  \
# 0    44919445  11/13/2019 08:26:47 PM         NaN  DOHMH
# 1    44919810  11/13/2019 02:49:07 PM         NaN  DOHMH
# 2    44916774  11/13/2019 06:36:48 PM         NaN  DOHMH
# 3    44920818  11/13/2019 03:53:51 PM         NaN  DOHMH
# 4    44920422  11/13/2019 01:38:00 PM         NaN  DOHMH
#
#                                Agency Name Complaint Type    Descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 3  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# ...

# %%
df["Created Date"] = df["Created Date"].apply(lambda x : pd.to_datetime(x, format="%m/%d/%Y %H:%M:%S %p"))

# %%
len(df)
# Out:
# 139541

# %%
columns = (list(df.columns))
print(columns)
print(len(columns))
# Out:
# ['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name', 'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip', 'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2', 'Intersection Street 1', 'Intersection Street 2', 'Address Type', 'City', 'Landmark', 'Facility Type', 'Status', 'Due Date', 'Resolution Action Updated Date', 'Community Board', 'Borough', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough', 'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment', 'Latitude', 'Longitude', 'Location']
# 38

# %%
df.sort_values(['Created Date'],ascending=True)
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 5360      15633828  01/01/2010 02:15:27 PM                     NaN  DOHMH
# 5364      15633594  01/01/2010 03:05:37 PM                     NaN  DOHMH
# 5362      15633605  01/01/2010 04:14:27 PM                     NaN  DOHMH
# 5361      15633803  01/01/2010 08:29:58 AM                     NaN  DOHMH
# 5363      15633599  01/01/2010 08:52:19 PM                     NaN  DOHMH
# 5366      15633054  01/01/2010 11:20:45 AM                     NaN  DOHMH
# 5357      15634275  01/01/2010 11:46:51 PM                     NaN  DOHMH
# 5359      15633896  01/01/2010 12:11:51 PM                     NaN  DOHMH
# 5358      15633897  01/01/2010 12:12:04 PM                     NaN  DOHMH
# 13484     19509458  01/01/2011 12:00:00 AM  01/06/2011 11:17:36 AM  DOHMH
# 13478     19507777  01/01/2011 12:00:00 AM  01/13/2011 04:10:07 PM  DOHMH
# 13479     19508703  01/01/2011 12:00:00 AM  01/01/2011 12:00:00 AM  DOHMH
# ...

# %%
df["Borough"].unique()
# Out:
# array(['MANHATTAN', 'BROOKLYN', 'STATEN ISLAND', 'BRONX', 'QUEENS',
#        'Unspecified'], dtype=object)

# %%
df[["Borough","Unique Key"]].groupby(["Borough"]).count()
# Out:
#                Unique Key
# Borough
# BRONX               27364
# BROOKLYN            48922
# MANHATTAN           36280
# QUEENS              20425
# STATEN ISLAND        6534
# Unspecified            16

# %%
df[["Borough","Unique Key"]].groupby([df["Created Date"].map(lambda x : x.year),"Borough"]).count()
# Out:
#                             Unique Key
# Created Date Borough
# 2010         BRONX                2067
#              BROOKLYN             3399
#              MANHATTAN            2867
#              QUEENS               1569
#              STATEN ISLAND         632
# 2011         BRONX                2174
#              BROOKLYN             3671
#              MANHATTAN            2461
#              QUEENS               1600
#              STATEN ISLAND         548
# 2012         BRONX                2125
#              BROOKLYN             3600
#              MANHATTAN            2857
#              QUEENS               1522
#              STATEN ISLAND         538
#              Unspecified             1
# 2013         BRONX                2120
#              BROOKLYN             3300
#              MANHATTAN            3018
#              QUEENS               1660
#              STATEN ISLAND         641
# 2014         BRONX                2743
# ...

# %%
table = df[["Borough","Unique Key"]].groupby([df["Created Date"].map(lambda x : x.year),"Borough"]).count().reset_index()
table.to_csv("table.csv")

# %%
df[["Incident Zip","Unique Key"]].groupby(["Incident Zip"]).count().sort_values(['Unique Key'],ascending=False)
# Out:
#               Unique Key
# Incident Zip
# 11221.0             4069
# 11216.0             3428
# 11238.0             3414
# 10025.0             3343
# 11233.0             2678
# 10467.0             2392
# 11207.0             2330
# 10456.0             2294
# 11385.0             2135
# 10457.0             2096
# 11215.0             2054
# 10458.0             2042
# 11206.0             2034
# 11226.0             2013
# 10031.0             1959
# 10027.0             1942
# 11237.0             1939
# 11211.0             1888
# 11213.0             1879
# 11217.0             1875
# 10024.0             1795
# 10026.0             1725
# 10453.0             1724
# 10002.0             1716
# 10468.0             1595
# 10029.0             1554
# 11205.0             1550
# 10452.0             1511
# 10009.0             1495
# 11225.0             1484
# ...                  ...
# 10280.0               30
# 83.0                  26
# 11363.0               23
# 10282.0               19
# ...
